# %% [markdown]
# ## Figure 2. Comparing RD, FD and BP

# %% [markdown]
# Imports

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)

#%matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import numpy.random as rand
import pandas as pd
import seaborn as sns

from lib.lif import LIF, ParamsLIF
from lib.causal import causaleffect_maxv, causaleffect_maxv_linear, causaleffect_maxv_sp
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## A. Some sample traces

# %%
tau_s = 0.20
dt = 0.001
t = 100
sigma = 10
c = 0.9
W = np.array([8, 10])

params = ParamsLIF(sigma = sigma, c = c)
lif = LIF(params, t = t)
lif.W = W

# %%
(v, h, _, _) = lif.simulate()
v.shape
# Out:
# (2, 100000)

# %%
#Make a plot
mx = 1000
tt = 8000
plt.plot(v[0,tt:(tt+mx)])
plt.plot(v[1,tt:(tt+mx)])
spikes0 = h[0, tt:(tt+mx)]
spikes1 = h[1, tt:(tt+mx)]
for t in np.nonzero(spikes0)[0]:
    plt.axvline(x = t, color = 'C0')
for t in np.nonzero(spikes1)[0]:
    plt.axvline(x = t, color = 'C1')
plt.save

# %%
#Make a plot of some correlated noise
